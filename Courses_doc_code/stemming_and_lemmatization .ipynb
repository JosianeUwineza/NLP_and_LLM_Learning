# %% [markdown]
# ### Stemminng and Lemmatization
# * Both they convert to word into base word.
# * Example : talking to talk
# * Stemming uses the simple fixed rules as it does not consider grammar
# * Lemmitazition use grammar rules or dictionary to convert word into base word

# %%
import nltk
import spacy
from nltk.stem import PorterStemmer

Stemmer = PorterStemmer()

# %%
words = []
